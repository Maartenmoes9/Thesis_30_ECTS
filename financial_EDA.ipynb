# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("TSLA_2022.csv")

# %%
data.head(10)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2022-02-28  271.670013  292.286682  271.570007  290.143341  290.143341
# 1  2022-03-01  289.893341  296.626678  284.593323  288.123322  288.123322
# 2  2022-03-02  290.709991  295.493347  281.423340  293.296661  293.296661
# 3  2022-03-03  292.923340  295.480011  277.533325  279.763336  279.763336
# 4  2022-03-04  283.033325  285.216675  275.053345  279.429993  279.429993
# 5  2022-03-07  285.433319  288.713318  268.190002  268.193329  268.193329
# 6  2022-03-08  265.176666  283.329987  260.723328  274.799988  274.799988
# 7  2022-03-09  279.826660  286.853333  277.336670  286.323334  286.323334
# 8  2022-03-10  283.816681  284.816681  270.119995  279.433319  279.433319
# 9  2022-03-11  280.066681  281.266663  264.589996  265.116669  265.116669
#
#      Volume
# 0  99006900
# 1  74766900
# 2  74643300
# 3  61623600
# 4  66999600
# 5  72494100
# 6  80399100
# 7  59184000
# 8  58648500
# 9  67037100

# %%
data.shape
# Out:
# (250, 7)

# %%
df_ind = data.set_index(['Date'])

# %%
df_ind.head(10)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-02-28  271.670013  292.286682  271.570007  290.143341  290.143341
# 2022-03-01  289.893341  296.626678  284.593323  288.123322  288.123322
# 2022-03-02  290.709991  295.493347  281.423340  293.296661  293.296661
# 2022-03-03  292.923340  295.480011  277.533325  279.763336  279.763336
# 2022-03-04  283.033325  285.216675  275.053345  279.429993  279.429993
# 2022-03-07  285.433319  288.713318  268.190002  268.193329  268.193329
# 2022-03-08  265.176666  283.329987  260.723328  274.799988  274.799988
# 2022-03-09  279.826660  286.853333  277.336670  286.323334  286.323334
# 2022-03-10  283.816681  284.816681  270.119995  279.433319  279.433319
# 2022-03-11  280.066681  281.266663  264.589996  265.116669  265.116669
#
#               Volume
# Date
# 2022-02-28  99006900
# 2022-03-01  74766900
# 2022-03-02  74643300
# 2022-03-03  61623600
# 2022-03-04  66999600
# 2022-03-07  72494100
# ...

# %%
df_ind = df_ind["Adj Close"]

# %%
TSLA_data = pd.DataFrame(df_ind)

# %%
TSLA_returns = np.log(TSLA_data / TSLA_data.shift(1))

# %%
TSLA_returns
# Out:
#             Adj Close
# Date
# 2022-02-28        NaN
# 2022-03-01  -0.006986
# 2022-03-02   0.017796
# 2022-03-03  -0.047241
# 2022-03-04  -0.001192
# ...               ...
# 2023-02-17   0.030562
# 2023-02-21  -0.053947
# 2023-02-22   0.017528
# 2023-02-23   0.006006
# 2023-02-24  -0.026020
#
# [250 rows x 1 columns]

# %%
TSLA_returns.plot(figsize = (12,6), title='TSLA Stock Returns')
plt.xticks(rotation = 45)
plt.show()

# %%
plt.style.use('ggplot')
TSLA_data['Adj Close'].plot(figsize = (12,6), title='TSLA Stock Adj Close')
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(data=ES_returns, x="Date", y="Adj Close")
# Out:
# <Axes: xlabel='Date', ylabel='Adj Close'>

# %%
# Daily mean log return
log_return_d = TSLA_returns.mean()
log_return_d
# Out:
# Adj Close   -0.001557
# dtype: float64

# %%
# Annual mean log return
log_return_a = TSLA_returns.mean() * 250
log_return_a
# Out:
# Adj Close   -0.389338
# dtype: float64

# %%
# Annual mean log return (in %)
print(str(round(log_return_a, 5) * 100) + '%')
# Out:
# Adj Close   -38.934
# dtype: float64%
